# %%
import numpy as np
import pandas as pd

data = np.load("datasets/synthetic_circuitnet_data/congestion/features/feature_0000.npy")

# reshape → (4096, 3)
data_flat = data.reshape(-1, data.shape[2])

feature_names = ["Demand", "Capacity", "Density"]

df = pd.DataFrame(data_flat, columns=feature_names)

print(df.head())
# Out:
#      Demand  Capacity   Density
# 0  0.950937  0.102156  0.715077
# 1  0.099282  0.839559  0.315999
# 2  0.656708  0.555306  0.797624
# 3  0.301842  0.433234  0.261212
# 4  0.481194  0.470966  0.972252
